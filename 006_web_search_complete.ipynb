# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 8096,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
print(response.content[0].text)
# Out:
# The best exercises for gaining leg muscle are compound movements that work multiple muscle groups simultaneously. Here are the top options:
#
# ## Most Effective Exercises
#
# **Barbell Back Squat**
# Often considered the king of leg exercises, the back squat targets your quadriceps, hamstrings, glutes, and even your core. It allows you to lift heavy weight, which is crucial for muscle growth.
#
# **Romanian Deadlifts (RDLs)**
# Excellent for targeting the hamstrings and glutes, RDLs also strengthen your lower back and improve hip mobility.
#
# **Bulgarian Split Squats**
# This single-leg exercise is highly effective for building muscle while also addressing any strength imbalances between legs. It targets quads, glutes, and hamstrings.
#
# **Leg Press**
# A great machine-based option that allows you to safely lift heavy weight while focusing on quads and glutes with minimal lower back stress.
#
# **Lunges (Walking or Stationary)**
# These work the entire leg and help develop functional strength along with muscle mass.
#
# ## Key Principles for Muscle Growth
#
# - **Progressive Overload**: Gradually increase weight, reps, or volume over time
# - **Rep Range**: Aim for 6-12 reps per set for hypertrophy (muscle growth)
# - **Frequency**: Train legs 2-3 times per week with adequate recovery
# - **Nutrition**: Ensure sufficient protein intake (1.6-2.2g per kg of body weight) and caloric surplus
#
# The "best" exercise ultimately depends on your individual goals, experience level, and any physical limitations. For most people, a combination of squats, deadlift variations, and single-leg exercises will provide the most comprehensive leg development.
