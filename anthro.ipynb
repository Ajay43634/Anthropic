# %%
# %pip install anthropic python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from dotenv import load_dotenv
import os
load_dotenv()

# Check if API key is set
if not os.getenv('ANTHROPIC_API_KEY'):
    print("Please set your ANTHROPIC_API_KEY environment variable or add it to a .env file")
else:
    print("API key found")
# Out:
# API key found

# %%
from anthropic import Anthropic
client = Anthropic()
model = "claude-3-5-sonnet-20241022"

# %%
#making a request
from anthropic import Anthropic
import os

print("Key loaded:", bool(os.getenv("ANTHROPIC_API_KEY")))
client = Anthropic()
model = "claude-3-5-sonnet-20241022"

try:
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=[{"role":"user","content":"What is quantum computing? Answer in one sentence"}]
    )
    print("Success:", message.content[0].text)
except Exception as e:
    print("Errzzzor:", e)
# Out:
# Key loaded: True
# Error: Error code: 404 - {'type': 'error', 'error': {'type': 'not_found_error', 'message': 'model: claude-3-5-sonnet-20241022'}, 'request_id': 'req_011CZg5GBkzDL7JLmPKbjk31'}

# %%
# Print the response
message
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Print the response
# ----> 2 message
#
# NameError: name 'message' is not defined

# %%
import os
print("ANTHROPIC_API_KEY:", bool(os.getenv("ANTHROPIC_API_KEY")))
# Out:
# ANTHROPIC_API_KEY: True
